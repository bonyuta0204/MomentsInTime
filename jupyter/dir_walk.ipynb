# %%
import os
import pandas as pd

# %%
root_dir = "../data/MIT_exp/training/"

# %%
for category in os.listdir(root_dir):
    for movie in os.listdir(os.path.join(root_dir, category)):
        print(category, movie )
# Out:
# breaking v018_0048.mp4
# breaking v018_0099.mp4
# breaking v018_0002.mp4
# breaking v018_0004.mp4
# breaking v018_0036.mp4
# breaking v018_0068.mp4
# breaking v018_0054.mp4
# breaking v018_0090.mp4
# frowning v186_0056.mp4
# frowning v186_0083.mp4
# frowning v186_0055.mp4
# frowning v186_0041.mp4
# frowning v186_0027.mp4
# frowning v186_0019.mp4
# frowning v186_0001.mp4
# frowning v186_0075.mp4
# pushing v225_0045.mp4
# pushing v225_0043.mp4
# pushing v225_0056.mp4
# pushing v225_0031.mp4
# pushing v225_0015.mp4
# pushing v225_0003.mp4
# pushing v225_0075.mp4
# pushing v225_0048.mp4
# reading v184_0098.mp4
# reading v184_0060.mp4
# reading v184_0088.mp4
# reading v184_0046.mp4
# reading v184_0047.mp4
# reading v184_0078.mp4
# reading v184_0054.mp4
# reading v184_0055.mp4
# tattooing v319_0090.mp4
# tattooing v319_0086.mp4
# tattooing v319_0096.mp4
# tattooing v319_0056.mp4
# tattooing v319_0022.mp4
# tattooing v319_0007.mp4
# tattooing v319_0000.mp4
# tattooing v319_0071.mp4
# ...

# %%
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pd.to
