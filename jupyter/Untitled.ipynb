# %%
import numpy as np
import sys
sys.path.append("../src")
from MITDataLoader import MITDataLoader
from MITData import MITData
import matplotlib.pyplot as plt
from PIL import Image

# %%
train_loader = MITDataLoader()

# %%
data = train_loader[0]

# %%
img = data.image_tensor()

# %%
np_img = img[0].numpy()

# %%
fig, axes = plt.subplots(1,3)
axes[0].imshow(np_img[0])
axes[1].imshow(np_img[1])
axes[2].imshow(np_img[2])

plt.show()

# %%
plt.imshow(np_img.transpose(1,2,0))
plt.show()

# %%
data.image_dir
# Out:
# '../data/MIT_data/training/breaking/v018_0048'

# %%
img = Image.open("../data/MIT_data/training/breaking/v018_0048/0022.png")

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7FC22C952D68>
